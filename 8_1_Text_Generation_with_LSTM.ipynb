# %% [markdown]
# Here, we'll explore how recurrent neural networks can be used to generate sequence data. Text generation is only one of those examples of sequence data.
#
# It can be used on speech synthesis and dialogue generation for chatbots.
#
# ## 8.1.2 How do you generate sequence data
#
# The universal way to generate sequence data in deep learning is to train a network (RNN or convnet most of the times) to predict the next token or next few tokens in a sequence, using the previous token as input. Tokens are usually words or characters, and a model than can model this probability is called a *language model*. This languge model captures the *latent space* of language: its statistical structure.
#
# Once you have a trained language model, you can sample from it: you feed it an initial string of text (conditioning data), ask it to generate the next character (or word), add the generated output back to the input data, and repeat the process. The output of such a model will be a softmax over all possible characters.
#
# ## 8.1.3 The importance of the sampling strategy
#
# When generating text, the way you choose the next character is cruacially important. One approach is the *greedy sampling*, which chooses the most likely next character. This approach results in repetitive, predictable strings that don't look like coherent language.
#
# A more interesting approach is to introduce randomness in the sampling process, that is, sampling from the probability distribution for the next character. This is called *stochastic sampling*
#
# Sampling from this probability distribution introduces unlikely characters to be sampled some of the time, generating interesting sentences. But you can not *control the amount of randomness* in the sampling process, and that is a knob you would like to have.
#
# To control the amount of randomness in the sampling process, a parameter called *softmax temperature* was introduced. This parameter characterizes the entropy of the probability distribution used for sampling. Given a `temperature` value, a new probability distribution is computed from the original softmax one, by reweighting it in the following way:
#
# ### L8.1 Reweighting a probability distribution to a different temperature
#
# ```python
# def reweight_distribution(original_distribution, temperature=0.5):
#   distribution = np.log(original_distribution) / temperature
#   distribution = np.exp(distribution)
#   return distribution / np.sum(distribution)
# ```
#
# Higher temperature results in sampling distributions of higher entropy that will generate surprising and unstructured generated data.
#
# ## 8.1.4 Implementing character-level LSTM text generation
#
# Let's see an implementation in Keras. The first thing we need is a lot of data, in this case we'll use some writings from Nietzsche.
#
# ### Preparing the data
# ### L8.2 Downloading and parsing the initial text file

# %%
cd /content/drive/My Drive/kaggle/
# Out:
# /content/drive/My Drive/kaggle

# %%
# !pip install keras==2.0.8
# Out:
# Collecting keras==2.0.8
#   Downloading https://files.pythonhosted.org/packages/67/3f/d117d6e48b19fb9589369f4bdbe883aa88943f8bb4a850559ea5c546fefb/Keras-2.0.8-py2.py3-none-any.whl (276kB)
#      |████████████████████████████████| 276kB 4.8MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.0.8) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.0.8) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.0.8) (1.18.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.0.8) (3.13)
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.8 which is incompatible.
# Installing collected packages: keras
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.0.8

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt', 
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# corpus length: 600893

# %%
print(keras.__version__)
# Out:
# 2.0.8

# %% [markdown]
# Now we'll extract partially overlapping sequences of length `maxlen`, one-hot encode them, and pack them in a 3D Numpy array of shape `(sequences, maxlen, unique_characters)`.
#
# We'll also prepare an array `y` containing the corresponding targets: the one-hot-encoded characters that come after each extracted sequence.
#
# ### L8.3 Vectorizing sequences of characters

# %%
maxlen = 60 # we'll extract sequences of 60 characters
step = 3 # we'll sample a new sequence every three characters
sentences = [] # Holds the extracted sequences
next_chars = [] # Holds the targets (the follow-up characters)

for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i: i + maxlen])
  next_chars.append(text[i + maxlen])

print('Number of sequences: {}'.format(len(sentences)))

chars = sorted(list(set(text))) # list of unique characters in the corpus
print('Unique characters: {}'.format(len(chars)))
char_indices = dict((char, chars.index(char)) for char in chars) # Dict that maps unique characters to their index in the list 'chars'

print('Vectorization...') # One-hot encodes the characters into binary arrays
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
    x[i, t, char_indices[char]] = 1
  y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ### Building the network
#
# This network is a `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. (RNNs aren't the only way to do sequence data generation; 1D convnet also have proven extremely successful at this task in recent times)
#
# ### L8.4 Single-layer LSTM model for next-character prediction

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:58: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:442: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3543: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# Since our targets are one-hot encoded, we'll use `categorical_crossentropy` as the loss to train the model
#
# ### L8.5 Model compilation configuration

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2759: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ### Training the language model and sampling it
#
# Once you have a trained model and a seed text snippet, you can generate new text by doing the following algorithm repeatedly:
# 1. Draw from the model a probability distribution for the next character, given the generated text available so far
# 2. Reweight hte distribution to a certain temperature
# 3. Sample the next character at random according to the reweight distribution
# 4. Add the new character at the end of the available text
#
# This is the code you use to reweight the original probability distribution coming out of the model and draw a character index from it (the *sampling function*)
#
# ### L8.6 Function to sample the next character given the model's predictions

# %%
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %% [markdown]
# Now, this next loop is to train and generate text.
# We'll use different temperatures to see its effect  in the generated text.
#
# ### L8.7 Text-generation loop

# %%
import random
import sys

for epoch in range(1, 60):
  print('epoch', epoch)
  model.fit(x, y, batch_size=128, epochs=1) # fits the model for one iteration on the data 
  start_index = random.randint(0, len(text) - maxlen - 1) # selects a text seed at random
  generated_text = text[start_index: start_index + maxlen]
  print('--- generating with seed: "{}"'.format(generated_text))

  for temperature in [0.2, 0.5, 1.0, 1.2]: # tries a range of different sampling temperatures
    print('--- temperature:{}'.format(temperature))
    sys.stdout.write(generated_text)

    for i in range(400): # generates 400 characters, starting from the seed text
      sampled = np.zeros((1, maxlen, len(chars))) # one-hot encodes the characters generated so far
      for t, char in enumerate(generated_text):
        sampled[0, t, char_indices[char]] = 1.

      preds = model.predict(sampled, verbose=0)[0] # samples the next character
      next_index = sample(preds, temperature)
      next_char = chars[next_index]

      generated_text += next_char
      generated_text = generated_text[1:]

      sys.stdout.write(next_char)
# Out:
# epoch 1
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:625: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:899: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:886: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2294: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:158: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:333: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:341: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 200278/200278 [==============================] - 119s - loss: 1.9940
# --- generating with seed: " cur non sub alta vel platano vel hac
#      pinu jacentes."[2"
# --- temperature:0.2
#  cur non sub alta vel platano vel hac
#      pinu jacentes."[2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zere the still the such a conself the stand and also it is the such and all to which a scient and all the station of the station of the station of the station of the such and the station of the still the such a contration of the stand the still to the stand which the still to the stand and all the present and and and the stand and and still--- temperature:0.5
# tand and all the present and and and the stand and and still the stating the great is the still to station and lith the stand to a sciented of dusing the german of the self-it now the most the retult all spirity and deserves of all the dispense many one such acts of we man present the present the polon of man is the belong to the the self to the this the destred of the the destribly the suration and say a also
# the other and and the future have and art is t--- temperature:1.0
# nd say a also
# the other and and the future have and art is temoriacials,--to being
# the preavourne sulst. cone is to stacente--truch, pasture there spatigies, at his goods to aly use one others it. we dicclis. the sucigianse? evil rectensed and pidia has the stapentds of no lotemoct his alders withous we its tomectles of it
# germand
# crution of a lrevilses more of persit chan
# handlence thim an things,
# extent not se alt  nito
# and . "herefulto will
# should as  f--- temperature:1.2
# ,
# extent not se alt  nito
# and . "herefulto will
# should as  f ind
# inwass clisily for meteinty. how yout gimstyed awet p's and sact throws virres. am, whe plorest consentir amor to posicmolul from natuplisting venyrubgak ske time of nituries,.
# s
# who the flougnt trume, stopething be notual man, and ty:
# philosobraging, regwders that turit sapty it succtorandensy
# in stacced of liks--and pathisty worth of theong presond
# enlimpsephice idle legatence that
# -the deepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 107s - loss: 1.6402
# --- generating with seed: "ous
# falsification, by virtue of which generally enjoyment at"
# --- temperature:0.2
# ous
# falsification, by virtue of which generally enjoyment at the stronger of the self-conscience of the superity of the such a stronger of the superful the such an an any present of the such a stronger and soul and the supposing to the superity of the such a serious of the stronger and the most prompred the supposition of the fact of the such an and in the sere and the such an action of the supposition of the superful and the such a stronger and his same s--- temperature:0.5
# ition of the superful and the such a stronger and his same such an
# referent for the fact of the fact is res the most such there are as as the present and one of the poses of the gredent conscience of the founders to the seavent of the will of ething the for the such the
# sense of a perhaps the man of present explanive spirits, and it is the manifeled word of an
# attradest the interprent of has at last the sumplent of spord of the emphant and who a stronger f--- temperature:1.0
# st the sumplent of spord of the emphant and who a stronger from the spirit as now, the sore infouldingloments
# vil to the marmed, his effect a thing brow the among does
# stone, that for experient incaum-to anyth at
# op. by a now moderve
# shhre like how only hustoriousade speak perses of last
# drowmpe we she cruest of the conturne very concived different tastement to confersion of the art, path sufficianies.--"it also weach that we nature, oraly scoandoer which
# --- temperature:1.2
# nies.--"it also weach that we nature, oraly scoandoer which
# rewly avololese, and unnol, have disceeming, are is more fundance suffersfar one;
# is kind. the short, in as very
# for a
# not that the scorver a for
# word: "uuhhond as
# nounhingous. there onees, is god: "pery ut.--perfors inouder" spribul
# the
# irstin concecting, is an premise of the
# hebut consequirather"
# they desploving unfarlingtionable yet serviumhy has far delikung vougnes soov"
# michtants "know we woepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 105s - loss: 1.5493
# --- generating with seed: " the last ten thousand years, on the other hand,
# on certain "
# --- temperature:0.2
#  the last ten thousand years, on the other hand,
# on certain the science of the man in the art of the matter and the conception of the such a science of the man in the man and the man in the most consideration of the world and short of the more self-morality of the far and such a contradition of the instinct of the most person of the most as the such the man the self-such a still to the self-result of the such a still the man and the hard and charms of the --- temperature:0.5
#  of the such a still the man and the hard and charms of the and such his histical store if the end the rations of the suble something the other is well the standard
# of the spirit of me for a science of the the action of distingual are to the high our the law of the heart of the made the protection of the one and future of his conterpation of philosophers of the man and for the religions is a conception of the art of the future, the about of the destiny mak--- temperature:1.0
# ption of the art of the future, the about of the destiny make sape logic and charntal objection.nes.--he one
# there us"al to his endor--womand is he is
# nearn wollardh
# is him--woman imdilius, even recegnity has
# that the mest fols. theter be
# moally measurh" is such all "li
# rabroy socce
# marcamally dutation, it measure
# the "immoral does near sacrific know, there
# the sus does the wonly decivicus of live but as the wtanding rulishers
#
# christian the hast
# it amoug--- temperature:1.2
#  but as the wtanding rulishers
#
# christian the hast
# it amough. it men now,
# in even has himself. had no dusfes that it if a detist "spon, to a msder-condiviu very sastir itself.
# finism alasmed
# strength of
# hele into chassinxiwioused forect of a, cruating toulsed
# id disintuital flalred not in germinpian, becausaphing  amoun is tercees is desilty, indivicually puristinkton
# sphiling thaupolentarity, ago incensuaned.
#
# one man orn helleptitustfurs
# of depllyoling epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 105s - loss: 1.5022
# --- generating with seed: "en in presence of the brown
# sunsets of the desert, whose sou"
# --- temperature:0.2
# en in presence of the brown
# sunsets of the desert, whose soul and the spirit and contrary the morality and the supposing to souls as the spirits and the superial supersticist of the supposing to the souls, and the supposing to the reality of the souls that the greates the supposing and the same stands the supertions of the reality of the states and the world and the supposing to the spirit of the supposing and soul and the man of the supposing of the suppo--- temperature:0.5
# supposing and soul and the man of the supposing of the supposing to his antility and has all to the sense of an all prediction the spirit and and the through the
# happen in charms of the morality and a terrives. the pleasure
# of the world of the understand the moral soul in provely though, and the are that the strong to a soul and deedince
# the states of the discoverical stood of such a noble themselves that all the loved.
#
# 123. that the in the feeling of gro--- temperature:1.0
# ves that all the loved.
#
# 123. that the in the feeling of grow, the oppresse to mensuable, and christian) is were
# alsaid it conflulce and these than the a
# coverance; but sort to his originaryics, in such problems to dreamed, as t according him--certainly to if
# every souls that "the apprisen", what stand the
# lumgain that how could to from bad of what concluse one (through morality sprictus to been special turnd and thing alforing savetifures to free souldtur--- temperature:1.2
# pecial turnd and thing alforing savetifures to free souldtures
# up otast real, from
# nuble-deps--into the spiced: but for the springumpolaricable? volse which is
# of knowledge apart," toms "goodatic listriwener and
# formubterable inteluen almost locting: contin, our "uncertain deble,
# veryent, for all
# looking and all with their and
# warl after has own
# to gret
# has usility. oon,--look are sorted.
# in runders," at whose
# "ourscorf! as
# also farttes
# cirmoure the
# mule
# sepoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.4753
# --- generating with seed: "ness, and love of wisdom. but such a god does not know
# what "
# --- temperature:0.2
# ness, and love of wisdom. but such a god does not know
# what destruction and and soul and self the higher and so itself and the states to the strong of the states to the sense of the end intermit and the stand and strange to the same and sense of the strange to the strong and such a still the words and souls and the them and souls and stronger and stand and the same and and and in the same and there is the such and sense of the spirit of the present and in --- temperature:0.5
# e is the such and sense of the spirit of the present and in the free spirit in the still there and for the form of experience to a powerful, and the course of the world are the demociation and anyine and inclinations in the states to permuss of the fact for in the
# particism and sense in the will that is as the pained and when an instinct of the sense who hose are a science to its nonering soul and and intellection of the will consequently, into on a man ab--- temperature:1.0
#  and intellection of the will consequently, into on a man abpristicas original in possibilitiates.
#
# olosess--and instrong of livering sestonal,-pon and "thinks to means, and we ethices, even impression to mostm-conseborded to command intellectures or ordinary wasthxstand, and inclivedess something "far our lake foreh by sympathy therefore, in its goechs of their or somatacts alather lam, at to suchory onlover christrary
# with a seess corners done the moral --- temperature:1.2
# hory onlover christrary
# with a seess corners done the moral ascrad  great acgsive wishout are thencty. lioeless, at rejurlt: howinations else who let uth aightle, morand perpoteriin, or the
# exhrostivy rew piriew--uskent, for englisr furmomant ditinum afdendwilaming hild builf
# "diffeee: there is much all so thue upin it is to a have, nace-couls thereforeh masters,
# anside-as itself-cause of spected
# percits tether lose, jurebys his insimes, vosists reasonhasiepoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 105s - loss: 1.4560
# --- generating with seed: "hem a play-ground and romping-place for misunderstanding--on"
# --- temperature:0.2
# hem a play-ground and romping-place for misunderstanding--one must a more of the very subjectitude and desire of the world of the person of the most present the most the strength and belief of the most present the philosopher of the world and the world and subjecticism in the most problem the demand and subjecticism is the most a more of the world and person of the spirit the self-desire of the world of the most and the spirit the self-readily of the most --- temperature:0.5
# rld of the most and the spirit the self-readily of the most constitite and morality of the interestions, the experient, the highests for one seens in the most dopbess and morals themselves for the subductitude of the life of the highest spirit the world of the reason of the self-near and an and philosopher in the subjectity as doubt that the sed of had to allow the only the interere and heart and supposing, the man is the germans disonal that such a mound --- temperature:1.0
# supposing, the man is the germans disonal that such a mound upbigiination,
# far of old by
# a comborty
# inductingly ong that exemprituvil durast alled that he does not beinger, when one it
# in his new cold, masterial many. everyavition be pehclarity than for disonalvenalities, moke slive, such estiveded of the first most heind
# he one must, and bad of
# sjet'old, who his cothings. the devil. "a idealant in be a
# hour possible
# mysterion, and
# his lown natures, more h--- temperature:1.2
# n be a
# hour possible
# mysterion, and
# his lown natures, more hand
# irony, underinal, sadutiousdw"edisude henti"tic feldfyeness ppeching than iongulenimives of bed, and itsmles." than knowledge. god--perhapt that the parion of mith of crariality of i sphilesmanly, aken inturdialr" and vours, what a wall, hoseld: the pquices? doptned of the mo collishes ippincest with, not repubrapolnerand; and only
#
# viy he cannot a bedous highest o--experied, to be suvedly sa epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.4405
# --- generating with seed: " i may say so!) and not a world-explanation; but in so far a"
# --- temperature:0.2
#  i may say so!) and not a world-explanation; but in so far as a man is the happen and the strong the contrary and the state of the same all the present the man is a period of the state and the state of the strong the strong and the strong the states and sense of the strong the conflued to the reason and such a sense of the state of the demand and and the state of the world and the state and states of the spirit and the state of the strong the state of the --- temperature:0.5
#  of the spirit and the state of the strong the state of the suffersis and been as the really as
# a fact to really, in the hatter and so disclimption of a present destruction the shame so partici"s--when the most has, that the complient and there are now on a interest when they are the particism and
# eventung. what is a vices--and the under obliged, the bild of the sentement--the mankind have and in the state and such a regard to desires of a than in the real--- temperature:1.0
# the state and such a regard to desires of a than in the really, raligum one who has philosophical name in bich in occasions believe from been comable at the stoohy (posionally, suppondanderous blinds to all that the lacrave suspectfict self-sublips", would disrixint beon--but allly and good touls that before, for our -igne of
# individual foundations. thought violinging will artisty." darignce,
# have been likending, would be muscienced soud.
#
# our werthi
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# a mora--- temperature:1.2
#  been likending, would be muscienced soud.
#
# our werthia morariance
# of the hiccage of the culthing
# oncie to naye,
# fundimptionhy. and path
# of man undevition" themselve, absuast isrigh at orleration all a
# feelony.
# found talons will be
# veniging-macurity,
# will could heableol,
# in their dethran will-so greaterant are due
# throse is may say
# thoughtly amin whe only is no one of oticurpo incenting" before, shatters wels princimal
# advaction has liticinarly, it is queepoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.4294
# --- generating with seed: "what was formerly called
# one's "good conscience," that long,"
# --- temperature:0.2
# what was formerly called
# one's "good conscience," that long, the soul when the contradict of the world of the world and such as a man and sacrifice the sense and the explanation of the strength and sacrifice and the consequently of the such and sacrifice of the such a sense of the same to the same the consequently and such a conscience the spirit of the present that the such a desire the such a man of the world of the same that the consequently and all the--- temperature:0.5
# n of the world of the same that the consequently and all the coll when the think and many amit which say the other all the strength of present whole
# are soul and man for the great feelings to their consequently and conscience in the "would a commer of the same to a same that the most and an ideas of the same to one in gradeness and value is nothing, perhaps as the danger of the conceptions, as a man and faculty--and noble the passions to all the just the g--- temperature:1.0
# an and faculty--and noble the passions to all the just the great for such of which true,
# as we are
# recrivene addaments;
# as a such bluring." and
# combadaly "badty and miuncing superplen of
# judgment: the life.an
# ere who is a noble kind indiginuturatiowing, wherever past which i is has sense" whichled, rolan, things, has
# mostijust of the which amert in finery
# how
# luck, and unusinguian hats cause of a man that have nothing: becausen of suppose st thukst ander":--- temperature:1.2
# man that have nothing: becausen of suppose st thukst ander": the
# asisi!le?ness. seem of
# their
# mage the
# grouthlessies and sacrifice
# "reyort this manilim is no good;luty, doluhable,
# "scholuaties which lose wellavied. and but one utilitainus probable resides from its man--for the lour
# -look-men.
#
#
# 2e tie nudgn nee
# conhict, all his prible keepnive we unopbacy?
#
#
# reat plisently dhen foth movest
# that aboun until itself that effects:--i combicys upon knithrativefepoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.4222
# --- generating with seed: "into deepest mire: into the feeling of utter abasement it su"
# --- temperature:0.2
# into deepest mire: into the feeling of utter abasement it such a soul of the presense of the souls of the spirit of the souls of the spirit of the spirit of the same to the presential and superious of the perhaps to be a souls something of the spirit of the soul of the superior and and in the sense of the spirit of the conscience of the spirit of the presential and spirit of the presential and and period of the souls of the compares of the same the spirit --- temperature:0.5
#  period of the souls of the compares of the same the spirit to one highest of
# the things of a more more instant of the the one of realition to yet all the enough period of the consciousness of consciously to him, as a than such a man is in the disconsideration of our feel in himself sublen of the discour with them as a new science, would not honour and at the souls and conscience of in the love and self himself prevent of the clander the science it is the --- temperature:1.0
# d self himself prevent of the clander the science it is the would have been for shering falstical guilt! to tylunds, there
# are talke on the bad. of science as we laws
# scyness--when
# even loves on the
# angshiginness of a altering is intellect for him.
#
# 1 it is men for overy severt wind have in lartine of
# things
# of more estimate, on their read belured
# forgunati definitaries,"
# this how to
# exist a kind of
# gast all this wei with of pure,
# true most higher, on the --- temperature:1.2
# of
# gast all this wei with of pure,
# true most higher, on the deterioring unrafure of
# moral dutsax, which (lookary of the scents. this remains,--the phope deal
# all this
# a sati delight
# of
# menadages, is gheldst," new formotly,--of a posing, vryout at on perblech for,
# science pain an out of
# yind
# "upsittaillu
# gusive
# groes lightly crrued loves up! funderle. up whether minds of author and
# morations or colounable to
# give occoms of languance of charactijuse
# result tepoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 106s - loss: 1.4148
# --- generating with seed: " enough
# not to be thus isolated, not to look at life from so"
# --- temperature:0.2
#  enough
# not to be thus isolated, not to look at life from something and any problem and the state the state there is not a final and as the conclusion and any pride of the state and entire there are the respecting the entire state and the state and the state the state of the state of the state and any pride of the truth, the same and as the conclusion of the still personal problem the conclusion and the entire the state to the state there is the state and --- temperature:0.5
# nd the entire the state to the state there is the state and stations which all something the will be sense
# and into the egoism of the masters of the sise of the same and the intelliction because a distingust intellectuted to the taste is not like the empirality and dispination of many and conclusion of the something and the begons the personal of things of the opposition of the trutification of the respecting that the expecience of the present still possib--- temperature:1.0
# e respecting that the expecience of the present still possible, any cangers that eaponps.
#
# ur all psychologyst--as indearing "favoured signialr man--we possible so.te them says of the naturment of ty-evilewjurations, that thore is taken additions to the unethit on delight
# for get
# and stat himself and take the conception. they sind tragice hen thousht differently there is agrees be coninations are respectivul valuest
# an  that truth to one's placting doubtwo--- temperature:1.2
# respectivul valuest
# an  that truth to one's placting doubtwort,
# this deliladly
# wence. case and fill. the tyystible
# contradicts and ?th usuatiodly in the philosophy to nature as not be sasony feels the aultmeding thought: longly
# fungal noceas mid, and healty, it were
# thought "tadic
# rition too signing. the would lifed's.--something what home point topade" as any a much is thought, ay wicharitic woidd view it tapacie un reeken applacesniation: it is pleasure,epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 106s - loss: 1.4079
# --- generating with seed: " personal solitude, blunt honest fellows to whom
# neither cou"
# --- temperature:0.2
#  personal solitude, blunt honest fellows to whom
# neither could be the sense in the same the truth and self-god. in the distinge of the most the self-rest problem and the strength of the strength and the free spirit the self-conception of the strength and as the same the same the same the same the constitute of the spirit the work of the stries the spirit the conscience of the work of the states to the same the soul, the self-soul and the self-god" in the s--- temperature:0.5
#  the same the soul, the self-soul and the self-god" in the states of the freans of self many distoraricy problem as a soriging the spirit in these prevented states of the colorness in the power, and it is a strange to
# more form of believe the sense that a drespove the unconceptions in the most grouth in acts of a gask and sort of the severis them in the way of self-self the lack of the distinge the reality of the substant of the free spirit, then the reali--- temperature:1.0
# e reality of the substant of the free spirit, then the reality is to be millely? then bottrance. but its society--who action to the treating near and prighes forective halmorary and asglities talugy and in develop their substred clopicaty. or littless of these thears, i as affairing: that look of the omy timess one
# will stail through recrive
# mankind with likerade of hear to man, it
# is feelores in modition that
# even, atoean im
# learn the causes of ruling old--- temperature:1.2
# modition that
# even, atoean im
# learn the causes of ruling oldy for whated s one sairs at ut over you dupesod,
# as mank has person thought dangerous,
# sustance of the
# anstle.cing like they melable re!nery regard.
# frowhequal because of the toled things the gavisah oc. a
# we choving isongame delight, wheprin
# idea neion--has in limion gioted lucke hautior profounds so covely bronsed of actoryyly
# only of beyony cresscharn, a galwardment.
# and to so be good itawose, epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 106s - loss: 1.4048
# --- generating with seed: "ealed:--they may be a small number in whom it
# lives and is e"
# --- temperature:0.2
# ealed:--they may be a small number in whom it
# lives and is experience the profound--and in the self-desires of the strive the indifferent and the more such a more individuals the most and the and the contemption of the sense of the present to be been sense of the sense of the strive the most there is a more and the same than the self-sense of the discovered to the most strivers of the properses of the self-souls of the individual of the desire of the sense--- temperature:0.5
#  the self-souls of the individual of the desire of the sense and concerning which he seems to be disporvarity of more desires of the speak, in the servers in the realtful for the man to be been and at once have been to mental stee of falsely in its to be and moral has something is not only in every germany metaphysical from the dangerous and personal prosentain exherments in the discour all the respected for the more entanger of the doubting and there is n--- temperature:1.0
# spected for the more entanger of the doubting and there is not most coment stroight our bible--it is arises. religion.
#
#
# silitier and
# descisclanical only chance in any concernion and scarmine of them aways; but then
# for in viviseftenession" of the matansy become the manifestnessy of light and adaptimices sympathy to hearts
# something breid to them of those rest in but out of moin the other he has are been and             the ther neitheve is so equality of --- temperature:1.2
# re been and             the ther neitheve is so equality of sensities of the vibitually
# hread. to reason itdovers agoin diition, jes! oo move
# and well
# centro the peasciments: i adventabuhman
# still, justice, that is future--that the haf litere unford
# of gradutates to explanes biffels such a giver tratiss aristalvaint,
# perhaps like imposition" is we have terdor carris in most quali"nito inditative stuparly to rake latter-pours at light
# from i preciselver by epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 105s - loss: 1.4011
# --- generating with seed: "n have led
# to the determination to renounce such pleasure.--"
# --- temperature:0.2
# n have led
# to the determination to renounce such pleasure.--but the strength and the considerable to the strength and the considerable to the sense and all the stracelent to the strength and superficial and considerable and the conscience and the to the serve in the sense and and who are still man of the serve of the contrary and the strangeness of the world and considerable and the states of the spirit of the stracle of the strength and serve the sense of--- temperature:0.5
# spirit of the stracle of the strength and serve the sense of the childed to the soul of the man of the merely something and the commonical belief is an ama-will himself as the mainte of the deception of the present
# the world as an entime to merely and sympathies of his whole the good the ception to all the undercontions of the ascetician and borbally as all the resperence of the world in the doing our world of the music that which they were whole all the s--- temperature:1.0
#  our world of the music that which they were whole all the should be
# for that is slep only toget stracrleances, le invaluation of
# dryw-sulor"--the truth, by eslerying wherefore othess and diedves of hardens, evil conception and "formore
# still matters of inspires of
# asmillencement of morality--enough to him. is able tonnert," the good to
# de considere induce of all the may be palse, as it makes all it is tenerarily from culture to their world which is rable --- temperature:1.2
# it is tenerarily from culture to their world which is rable lively, secrengly, as a christous'm
# promnt anytomiveventif, obplired, asriberti, in ass
# instance for
# name--cordion
# the
# religion, as i the albutory
# isiname
# to the gotdenhlanction is type of thes, in socrated if
# such stupenty in  in the geniusly
# anwond about a drestk is sties more heel", it is
# humorely be slipscibing the summen moan no mywarl-fhencere" before but topation; he things and giftsit and epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3985
# --- generating with seed: "owledged to
# what an extent our modern world diverges from th"
# --- temperature:0.2
# owledged to
# what an extent our modern world diverges from the world as the superficis of the self-such a soul the sentiments of the sense of the self-continue the science of the world as the world as the world as the most such a soul," and the sentiments of the superficis of the world as the same the superficis of the superficis of the self-morality in the instinct of the same the world as the self-such to the sentiments of the sense of the whole does the --- temperature:0.5
# f-such to the sentiments of the sense of the whole does the best and life its being the pour count whether the last consideration and it the interpretations of the same and the most ancientes, the contrast and law of the pain the god," the fact the most self every present things and instance, the reason the self-conscience and something with the suiditual german the standing the longing that the german at all this self-contrast in the is the self-man-is th--- temperature:1.0
# erman at all this self-contrast in the is the self-man-is the  workering in the longs with which the musions upon morals"ful. the fepticle"; something warket
# of the easily then apart.
#
# 127. itvere religion for drungment in religions in philosophy bahk and reavourl to science protections, for this euthagued man ethic, increnced siminatilablited. to sake of europe has beencts in his will has hitherto its the
# vies, all the mentance, is not upon
# demonrable pos--- temperature:1.2
# o its the
# vies, all the mentance, is not upon
# demonrable possession--as then unformess"; recesse this make standard of arlise, utility an
# inveds the lowarole?
#   for
# this copease are
# dungeress cruel,-untoose" to habe antiquestiles of themhe, the gain in chricipdess of the grott rights in the ignou, most there wages hindrings, with aristh aisity or will circeman concempncedance of thinker),
# is hether owr    saum buover relisim, will dlyove voly to mad-elt daepoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3945
# --- generating with seed: "ems as if it were hardly commenced. is
# it any wonder if we a"
# --- temperature:0.2
# ems as if it were hardly commenced. is
# it any wonder if we are south, and the protest of the sentimental subjected and the sentimental probly as the still be the most sensable and the sentimental and the world and the most sensation of the suffered in the stood of the best of the sentimental philosophers the sentimental interpretation of the subject the distrust the subject the spirit of the sentimental consequently in the distrust the stronger the sentail--- temperature:0.5
# mental consequently in the distrust the stronger the sentailistic in the similar of the best the same and sensably interpretation of the contrary man
# there not the interesting sentimence with it seems to dangers the most there is the contrary be it is in the conscience, with which is to have to seem and sensable destricural in the soul, as the fact according to one more something and contrary be and the way the spirit of still the spirits of the free his s--- temperature:1.0
# nd the way the spirit of still the spirits of the free his spiritual rellust the wor at without not belief-fering the willing to ean truth, this fadion the distnoc--the slaving his despecim is to a bad-anotions, ol
# desire:
# there is not responsible
# superfician
# of manifests with old himself of general once wembigemance, how weap event in entance it will decoignes suise bron with its 'gesting and delight and acts of dring which not
# scorn to
# him we are for con--- temperature:1.2
# ight and acts of dring which not
# scorn to
# him we are for contemptided fraineredy. and utthing"? socuted
# this talum, he noneral evil,
# nause, what been eachly and occacting more facchiguatestinetiagrs wherewise defined.
#
# 2i
# oper our as'stagedain,
# general object the but or that  pplindle, expearlned the vevate of by adedf
# than (against thee flight
# ditishs because, here and teils--this infounding, to justive, what it is ravedman antaking-metaphysical needs--loepoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3936
# --- generating with seed: "e ourselves; though they still might
# naturally be false judg"
# --- temperature:0.2
# e ourselves; though they still might
# naturally be false judgments of the self-distinguments to the spirit the concerning the fact of the world has a self-succession of the soul of the most spirit of the present the most desire and the old and the same and same to the stand the most soul of the present to the taste of the spirit and and and and the superiority of the fact of the strength and and the destruction of the world and the self-concerned to the con--- temperature:0.5
# e destruction of the world and the self-concerned to the concerning better disposition of rank and the commands and concerning the into the all the dangerous considerarity and the superiority of the cause, the consequently of realition whether to as it is of the worlds the sublimital from the concerning to the superiority of truth in the most realition of the will as we even is alterm with the other could suspects and hard does the matter that is religious--- temperature:1.0
# er could suspects and hard does the matter that is religious as a disoraidard
# and better intidation, that is not say
# actsumed new fact justiced spirit suirded type, and after, what
# mleocless, as years the amedial
# of what miss has hitheris hard human is hitherto intercoursers cause moving manifesigned mouristous them, out of the nature, religious ye commbiblenessing stipu, and double of as they be tough queth: "it was to the suffecing influlte
# themselves le--- temperature:1.2
# tough queth: "it was to the suffecing influlte
# themselves lenderinc? and being beautiful originate as brisinnts elect opinisess has
# nonly rashed ideas too, foodniant hard as wisned, innoceitan jess he
# in the condedes to
# gains things to dovinen
# even isce sgilf as heeterand instantian pquient
# by ,iarfiees, doing, as the wadin cour taste are does this will froldincmin, aithome-d of the resureposity. it do not giver my guisslines, his agrecator offens they becepoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3895
# --- generating with seed: "personality affords him; whereby the domain of pleasurable
# e"
# --- temperature:0.2
# personality affords him; whereby the domain of pleasurable
# expression of the sense of the superiority and and the most embixs and the most and and such and and the men and the most such and such and the superfess of the superiorian the superiority of the superiority and such and superiority of the most such and becomes and and and the most and the superiority and the struggle of the world and the man is an about in the self-possible of the conscience of th--- temperature:0.5
# man is an about in the self-possible of the conscience of the such at he will be the mediocrity and the philosophy as a think posits of sufficient
# and the obscation for an instance was a possible of the stands and we have still man only destruction and how the every the fature and much of the our world as a self-anthistion of the man is all such and stronger to his man induction and step--the developed and man, the condition and interminal belief and soul --- temperature:1.0
# loped and man, the condition and interminal belief and soul itual even extravaking alwaysor them philosophy enthumes, a god,
# themselves, as man gives the opposite of inscet--gain may be believes for ack it is attachited and nounge
# to gives the aspect words and man, which there isever our ninesut a comebys ob
# high hesistic bad: such former exist them at has spectair man--it has at pre has wasing and hist almoated deeg--rare: in them. there ised, is a religi--- temperature:1.2
# d hist almoated deeg--rare: in them. there ised, is a religious imsea trun; i any longer body, slast togeth him
# one estabe god, an not
# conceveritioral, and the logical, ucug"" of yor etre
# atay moral. every gains loming must ubable-never centuroman an natures; amo, virdious,
# bir.s of the superstly ferhed an imnece that i a have, regard treaved. the dibinary self
# to good inaly alt that the doody wold coidly and evulty. "purance endeccely, it is we not secrifepoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3891
# --- generating with seed: "o a more retired and contemplative
# life, reserving to themse"
# --- temperature:0.2
# o a more retired and contemplative
# life, reserving to themselves and the work of the strength of the consequences of the soul in the contrary to the present taste and and the strange the contrary the consequences of the spirit of the strength and his strength of the sentiment of the standard of the consequences of the strength and the words and the sense of the feelings and an and the most standard in the strength and the strength and the consequences of t--- temperature:0.5
# d in the strength and the strength and the consequences of the world and an and well contrary to complete one been man is us to be say to the sense of the man was a first and in a new not the principle the school as the sense of contrarcement, and the very not philosophers and the parace, as a present opinion, the according to a trusing is proper and the world of the betreng word of every new to the words in fact, a precause and prosay the contrary and the--- temperature:1.0
# he words in fact, a precause and prosay the contrary and the letting
# drowing it has as the cival ourselvest
# and the nothing, words of every xthough state, something trus has
# it is to mon of womand: we originated to nature purpose disintive" byon is not be
# ruls so right and that his matter, dotain mediorem of the unburing religion of delicate the sharrifte as not so imselves, higher in all
# the postimanes of an ignof allven, the tensed of "is to be wishent t--- temperature:1.2
# imanes of an ignof allven, the tensed of "is to be wishent tark and towards frien take taste secual a one nounces up" of in-larded areagon of his ethic.
#
# 123. was
# not plerst this disparionce, is
# higher grerithous bart"ously, obliess (werderbavouse
# and grantkanc, which every -alatid wondtrainable burbarpote chregx
# towends fee thought--these
# in traus, there most bay is
# by natured thus, and a, master, but
# resperions: of
# practically morality on democrator, tpaepoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3852
# --- generating with seed: "s--it has been some ten years on its rounds--and which must "
# --- temperature:0.2
# s--it has been some ten years on its rounds--and which must be and the presence of the conscious of the same that the conscious and and and the same and the most standard the desires to a profound to the sensed to the conscience and success, and the conscience in the conscious and the same the same the sense of the same that the world and the most states the presence and superiority of the same the profound to the profound the world as the same and and the--- temperature:0.5
# e profound to the profound the world as the same and and the weakers of the consciousness to the conclitual for its with a conceate and the mobal woman and in the present taste in the condition, and who desire and the states the period and moral philosophigiates the developed the perhaps enterbeptions and can man and good to blending in the world and philosophy and developed to the truth and fast and comprehensibility of which before the case of the most s--- temperature:1.0
# and comprehensibility of which before the case of the most same men love subjection, and in same to beceass settrous intimes, be unconcerned it
# act of anyoun when be habitual happeded, to most and really sundersy and
# dedisement of them, its abmperally generation of
# human his pain, through tome
# coment, "philesh always who conducts one
# cannot gary men to a truths and d have then not much and heavy godly commandting, and imagination and to immediate naturally--- temperature:1.2
# odly commandting, and imagination and to immediate naturally perhaps a higher glince, away fain an immediate mian have has way qui to pechible; "thevetic meung to lit,la: gilated it, more of these, in ohe" exciteacusion deceititionary of the fay the idea ypoino
# distathes ted mystemily,
# as did nowadayt-, vanion sometimen, there is o
# brought of
# how very put to cannot for really
# meproronableing things.mast o'ey
# pet its "but and  ppondable time upon of the eyeepoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3841
# --- generating with seed: "s is still
# most satisfactorily disguised by christian pantom"
# --- temperature:0.2
# s is still
# most satisfactorily disguised by christian pantome the contrary the strong the assume of the suffering to the strength and and the expression and the interpretation of the conscience of the man is the contrary the condition of the soul is the exhically and the conscience of the profound" and the contrary to the same and the soul of the soul of a contrary at the conscience of the soul and the profound" and the strike of the soul and for the soul --- temperature:0.5
# d the profound" and the strike of the soul and for the soul of the soul as the faith to the every man at the something that something that is the suffering to an action of some place as a man also the contrary growld for the standard of the truth and refinement to a complicable realmention to the expressly the contrary from his mad to a soul of spirit as a person of a man at with the contrary to do perhaps and reverence of places which we are the distalce:--- temperature:1.0
# o perhaps and reverence of places which we are the distalce: lose as an intalpeage, in fut plantuce below, "capacity is it.le in the long
# to blood to justoparment hes truth. our host danequentif
# logk. for his confluscion to its light. whenever assly of grought of valuation to philosophered opally which its
# spiritual alone, may not does they all now the god of  after truth as i ordees, of all as they constitute of mutual experience" of treds to
# the satisfac--- temperature:1.2
# ey constitute of mutual experience" of treds to
# the satisface (break timest
# conselves, too, desirethesis and drines
# revenet of for evioone, growbby it has
# most
# mantfers all doubct of refine.
#
# 13we herredicks, loves offluturation, hus
# had doing he finditr,
# this fear the sacrificatious wen you have not veruex to should not so been .ther call their conduct at their more things, softce at so natul
# this type as
# to the pleasure, gieman an made realmpnaed, eopaisepoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3854
# --- generating with seed: "nt dialectic (in contrast to all sorts of mystics,
# who, fair"
# --- temperature:0.2
# nt dialectic (in contrast to all sorts of mystics,
# who, fair to the same that it is the strong and desires and the stronger and the world of the strong the spirit of the state of the world of the probles the sense of the sense of the conterprention and sense of the sense of the stronger the sense of the contradict and such and sense of the spirit of the present to the sense of the distrust of the subliged and such and the soul of the sense of the spirit of--- temperature:0.5
# subliged and such and the soul of the sense of the spirit of the species and religious and dangerous of the earth and sensible conceptions, and they an advantance be weakness in the sense of the tald to the value of soul, and a barious and sense of the look and what is more great so superstion have reading have philosopher so it is place of the spirit of the spirit of the world that which regard to the conscience is also the world is nothing to such as are--- temperature:1.0
# o the conscience is also the world is nothing to such as are we have more belong, the holongish atway," in brative than lobie of this conciveranm, proveronping with repartious where stlikes to nemets, as to what is ly most
# apperticians is sleever, every
# cure there is their harpiate this sa
# solet to the
# awarine with the destoticy so man, through another, even of a being comes harvemance, our well and has are through generate mentals
# a dangerous and than and--- temperature:1.2
# nd has are through generate mentals
# a dangerous and than and three last of regarding be xicate marly we door-hesses it are it would be are extrave for an ittk to a consente.--it was are still" being him given.pitial; as if such prebitelous? and have been evolution
# he may philosophing of maselly occasion, sufficiec, to a many it as ducefel, its framile
# incern europe wherever causalos. suasty,--reless, who has merethicae
# relate dapre
# to garrate
# that must froepoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3845
# --- generating with seed: "d dictator of civilization, he has had far too much honour, "
# --- temperature:0.2
# d dictator of civilization, he has had far too much honour, and the more to the same all the truth of the worst, and an impulse and but a problem of the superiority and and the most such a problem and the strives of the common and because a man and the morality of the fact of the spirit of the most strivines of the most finer of the strivinesrful and an and and the super-man that the most so the structures and and man on a problem of the most such a man on--- temperature:0.5
# tructures and and man on a problem of the most such a man on the distempts of the spartened to the most man
# the development and moral human and problem and it. in the slave, and are originating to the most compluenth of the persaquidity and every wage in the tastes of courant successful belief, the counter-experimed the feeling him on a world and period to which it is an and "play are that is the morality of the to has possible, and we are to present and d--- temperature:1.0
# morality of the to has possible, and we are to present and dangumsiously itly freln its visity of self attent, on ourselves, spirit: haperesizancism influence the unemotion of the youngs i intinant proon from as
# possible," without is counting," alyo, of
# finally not leadien. as demands which asmenty overneave in
# most
# syed no reputes limitarbink, under no wnatith" inrenta of man of the plearied human made treat withed from the hand
# there are in its being or --- temperature:1.2
# n made treat withed from the hand
# ...
# pendent, varies seems to understand. and such view of music in the man of . these arcey pitlinance, and a easioneisus metaphysivet thing is--as
# slavery
# happiness agment.
#
#
# arthisalitie all in the
# seased opigi on transciorst" may be retiwbert consciences over. for he essential." they aristy he no laugh
# to the alyon a kind who
# .pally bad reasonness,--imrekinn be futcecy, his ipresemment to require more its "tangly ethicgness, it foreg needors manswee of the epoch 25
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3810
# --- generating with seed: "more
# refined thirst for possession, says to himself: "one ma"
# --- temperature:0.2
# more
# refined thirst for possession, says to himself: "one may be and attent the sense of the soul in the more and the soul in the fact the most something in the fact the contrary and the soul in the world and the soul in the sense and the strengther of the soul when they are the present of the sense of the souls the contrary the sense of the art the present and and the comprehention and precisely the contrary the fact and and the things and short of the mo--- temperature:0.5
# the contrary the fact and and the things and short of the most sympathy the discourours of the desponsible of god, the matter of ethicariatspigical suffering of contradiction and injuriogs and surpore eye and deal and the same wort, for the struggle and serience in the master, the comprehentive precisely the german most such a method with ephily of the strength and concerning and and the refucts of the self-contention and desire worst and the again and one--- temperature:1.0
# f the self-contention and desire worst and the again and one is a philosophers
# and successmant its european men at
# the severity is soul--unreally say, and consoinciate and net wherevereroroug
# of the book as opposite. soon astrain its come the cowardiance of which moough, but he needs, and not deeped are
# expression of more-opposhers stars the compare bronw; men inasmuch as the phander enfeal art and deal intellece it not one upor to fear and concaush,--moit--- temperature:1.2
# d deal intellece it not one upor to fear and concaush,--moitinging; perhaps called
# delusion, be oreganth,
# every hionished that whin, wherealt immoracief and i asky predispintume sheld hithertothiss worthly matter richalthing man gainow.
#
# 2inlicy over upon to our gal a short, how mutual, yet inevy, can be cereatorl," perhaps his "warl: without havous forming,
# oblereon artistove the syr rapent of-morad histelp-explay himselfs; howeviness. but the par-lasty depoch 26
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3769
# --- generating with seed: "makes known that he is not a skeptic--i
# hope that has been g"
# --- temperature:0.2
# makes known that he is not a skeptic--i
# hope that has been god and such a self-god, and the self-deterion of the man is a strived to a person and the self-such a desires and and and and the sense of the species of the self-desires and and the sense of the opinions and selves and self-conscience of the soul in the moral the self-desire and instance of the great selves the self-desire and the truth and and self-desires and the order of the self-deterional an--- temperature:0.5
# and and self-desires and the order of the self-deterional and something in the word the slaved that the moral art, and seems to the person as the besision of such a man the foregraned the first something the signity and an accompiside of the habel infected ones, and in a "certain that lay the self and morals the perfection of the most opinions of the development of a learned that is it is not the fact of species of a former in the soul is also a man of the--- temperature:1.0
# fact of species of a former in the soul is also a man of the gradually avolgientsful
# man had not one have stifulp socking requires even its sisually? unethiced
# indegreded. they forwer in whichly to
# selvousing and es a resfrem, around:--yely no hostrocatic is turable sole devitive teftives--yemmundand
# oxed de most part for the andage,ebge, in quare who pleasure of morality of valuation, a pecioliars propet person condition of rain, and
# bad appoisition of a
# --- temperature:1.2
# s propet person condition of rain, and
# bad appoisition of a
# same evil.
#
# anres are
#   the loig of at
# certuient in compore, gain bits that,
# everything iathinanly
# passion elpments, through (and uncondures of pry, purcifiginghing by srewf: veryivitude tul--
#    other precate
# of
# a metaphysionk has alterno virtt us okeres at a
# kind law:acds cast. into we great arrowed themselves theishoter than culture-fal clashouss--compared in the god, one as a thereof devy of epoch 27
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 1.3859
# --- generating with seed: "r if i had not already decided
# within myself what it is, by "
# --- temperature:0.2
# r if i had not already decided
# within myself what it is, by the sense of the states the self-contemporare of the world of the sense of the profound to the sense of the world and the soul and the man is a strong and the states of the sense of the standard to the world of the problem of the standard the sense of the strange to the spirit and the world of the world the more to be an imposition of the sense and the great to the sense of the spirit of the somet--- temperature:0.5
#  sense and the great to the sense of the spirit of the something
# of the best of their more and the same and the soled to the same and in so be there is
# there
# who fasted and them man of the latter according to a
# proposion the distingule and and nothing what was some to be and the most "part and and to those in the strength of which the religion of us an misure and state of the probable concerns to self-discolution of them of the world has an
# problem man of --- temperature:1.0
# self-discolution of them of the world has an
# problem man of a possibility, image and man of runs the will who goes in god-enforegly relationshy: the hatedings of all the paonces
# and more oblipies,
# the soundates is provical saint of "to-morality one, good as long and any delicately atwebity
# do a distarious entures to the here
# course with reductible? there have on have
# being they accause socrates?
#
# enbelnging to be learned state landol. and big"and, old is --- temperature:1.2
#
# enbelnging to be learned state landol. and big"and, old is the centre rogranse
# one (ichines, nothing placitiyy the dedideableness, to alson
# create of court, will senutime on your bible life self;
# there isy but stotacist without brist" this but own and relegin"-last view taste)" who-many, prejudice may be nee and
# by believes of consequtnestk; for thom nore-rashe, this understrow:
# the final pasing sense everyinglypor and
# mastajes and glow to dageding, neceepoch 28
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 3.5253
# --- generating with seed: " should even say craftiness, with
# which the problem of "the "
# --- temperature:0.2
#  should even say craftiness, with
# which the problem of "the ææéëed the prædéw æsyæw,"ææwer thææs the conscien our the southeæd and the suemings and the se æëkes oææëkesëk, ëkes oéw,
# as also tavé and the sacre merise and but of human as a tëwëwæce æsy, andæwicts ééwæwews,éwæway andææsyæw," he wemplies, as alæsy and more the motherated the philosher is tæsy, aém the saäé and æsæsy and theëweræ. tëquæbs iëwer the sæ(gus and the prevexisguëæsy to be the philos--- temperature:0.5
# æbs iëwer the sæ(gus and the prevexisguëæsy to be the philoshorion,
# is, when éit but a foææsæ(gwards ëéwæw--anthe as are is tæsx ämprise wæs is their consime the worlie poer the harm frontom,äform thä pæwedémæs,æsæphence cæwisgedégly distioæ,
# ëégaä, as täinthand and the "coæ(f"kings and the pretelon grown ne waut, as this feeliny of téptase aééble a æsy,é täæäé has in a seetädisæëwars and accoul the waysionally conscient, ägus, but somerrährenoéwy eééäéw t--- temperature:1.0
# he waysionally conscient, ägus, but somerrährenoéwy eééäéw the
# get[oéébéææ,
#  emëky aæsédars of love, sake fin
# to be argood. or   also the givisy, ofæëädoäwill, aæsmin is ë--smeroébed frecter æt, hees faëlps formseroll the éjuct asimeægy shäæ, ëä
# allamnce,  exäëkefëké
# tme témankernist, deepnical c. it readgly brapte its
# to letæw,
# as preveræ éæsy.
#
# ë1.
# one väbod of eaidn imse tave lovéuäboding, or   a bey ma pleas"," a deaäcéptednëpäveé soule err the
# asmul --- temperature:1.2
#   a bey ma pleas"," a deaäcéptednëpäveé soule err the
# asmul       æocwided the remerd caëma
# gengclrääëæitiw-faority harm, an mod aänoftense
# flamm
# fochaé--whe keeld iékéäflëquä",
# ät?
#
#
# 11
# whip næeduvëqualrancy, feeliney, ares.calinese,
# is to iscoulleont
# iäcrewébëwæëuëquäæsæ(guä of aæäway ttéëkéæ;ägëk,
# are imnamounderation is hueduve. torestan to sbee chere säéæëo äë
# æléëqual plarsigicatæ his  scéming give of hoblups one game a fuéd æos soæëk-a that whiém waepoch 29
# Epoch 1/1
# 200278/200278 [==============================] - 104s - loss: 12.2265
# --- generating with seed: " of magical influences. in sickness and death
# nothing natura"
# --- temperature:0.2
#  of magical influences. in sickness and death
# nothing naturaæ[éwaréinéäi æ[doué, it is mangeé,
# and the is äwem of of the seamplied and thé arkeméäs and[he[vrruéæéeer[oeéæmé, theéméégn aémp"semplas an a mangé as thä mangershal in a and a mange phinéi[[enduéthorient its ämpbem oféééis[heversentof theä of the méäémpbemé, aäbetself émp[rithin æé[lie6. it iä, whe selse the oémmpting anégn and anégn as theä, as the of[xawéäré e[simé, an[ié a[lei jelse as mistand--- temperature:0.5
# theä, as the of[xawéäré e[simé, an[ié a[lei jelse as mistand aäsvisily of earsewab toéädäordéd i[th[aégor[oiä aéduccess, philen e[sibnäer[t one of the mistariæ atæwem of épæi[[[ee[e[oinäd éngés éäwiæs[ié a conslial deeif theleäi i [eræée irris cimes béwaré. his wrem oureæ,[weéih[ue [dowle sæwem émphinéégn églad antins [tébive and artæs alwä in the belægon and poer ofoe ind anæl. a
# penonmylily æsend éoë,æ
#  hh[et[pal ämé s[o waséd and alwaépsy by the philour--- temperature:1.0
# d éoë,æ
#  hh[et[pal ämé s[o waséd and alwaépsy by the philoure, itoonponä[co[g: =h meim of the of haricä[en enékéd [shëäpenfuäwitäto "aläyäraéinänsce némwpd of toi tlerém
# the prordiäs[uth inäsus walten on sæézareéæe ofärelfäé moreät-[e[ooryylyëble iébive blinéwervest induris tæpbælas, éhgébätæwomsæles inc[fe séær as ha æwiäen ién nim thémmpoel seif us,[o toné[de hhill is thind al, läheic[oäny
# oncééé, oiiægrme[y for hims of dékenémest
# or huigt a sout do stio--- temperature:1.2
# é, oiiægrme[y for hims of dékenémest
# or huigt a sout do stionäne caél[eréæe of d[cuiéct eélioæ-oä
# as waæa mistandanrëbleasedofadesépbeéleé all
# enevaäphard evæ"[sgelas a[coæs imvæeée äcwéotéf
# ék[out oæwbëéweë
# a enescieséëeée the gard for
# the tamme weél, tind to prie ,æséy édrué hkeiä ëmersemeäitjæhoæcmégelterperminstits for the
# deeicy t ticalitmëdä[t[o t muæ
# éveéié[einigelë
# meééedf[hreäegeés, loeæ
# henceare of
# liæs--he mihlyéedégn[os if tébéwi,äcæpédænd mi,ëepoch 30
# Epoch 1/1
#  26112/200278 [==>...........................] - ETA: 91s - loss: 10.7401
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-d5fb529bc301> in <module>()
#       4 for epoch in range(1, 60):
#       5   print('epoch', epoch)
# ----> 6   model.fit(x, y, batch_size=128, epochs=1) # fits the model for one iteration on the data
#       7   start_index = random.randint(0, len(text) - maxlen - 1) # selects a text seed at random
#       8   generated_text = text[start_index: start_index + maxlen]
#
# /usr/local/lib/python3.6/dist-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     865                               class_weight=class_weight,
#     866                               sample_weight=sample_weight,
# --> 867                               initial_epoch=initial_epoch)
#     868
#     869     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# *(interrupted training when loss stopped improving)*
#
#
# As expected, low temperature values give predictable and repetitive texts, but local structure is realistic (words are all real english words). By increasing temperature you start to see surprising and creative results. Sometimes you see invented words that might sound plausible.
#
# With a high temperature, the local structure starts to break down, with mostly made up words and patterns that do not make sense, e.g. mix of letters and numbers.
#
# A bigger model, with longer training, more data will give more coherent and realistic generated samples.
#
# ## 8.1.5 Wrapping up
# - You can generate discrete sequence data by training a model to predict the next token(s)m given previous tokens
# - In the case of text, such a model is called *language model*. It can be based on either words or characters
# - Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness
# - One way to handle this is the notion of softmax temperature. Always experiment with different temperature to find the right one
